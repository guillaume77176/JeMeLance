# %%
import pandas as pd
from data.load_idf_10_24 import load_base

# %%
url = "https://adresse.data.gouv.fr/data/ban/adresses/latest/csv/adresses-83.csv.gz"

# Lire le CSV compressé
df = pd.read_csv(url, compression='gzip', sep=';', dtype=str)

# %%
df
# Out:
#                           id  id_fantoir numero  rep  \
# 0           83002_0120_00048  83002_0120     48  NaN
# 1           83002_0100_00045  83002_0100     45  NaN
# 2           83002_0280_00009  83002_0280      9  NaN
# 3         83002_cessl1_00011         NaN     11  NaN
# 4           83002_0040_00001  83002_0040      1  NaN
# ...                      ...         ...    ...  ...
# 400538      83005_0090_00020  83005_0090     20  NaN
# 400539    83005_rv734b_00050         NaN     50  NaN
# 400540  83005_i1b0ex_00767_b         NaN    767    b
# 400541    83005_ye3pd7_00085         NaN     85  NaN
# 400542      83005_0050_00001  83005_0050      1  NaN
#
#                          nom_voie code_postal code_insee  \
# 0                       Rue Haute       83630      83002
# 1                       Grand Rue       83630      83002
# 2        Place Sybille de Foresta       83630      83002
# 3                     La Placette       83630      83002
# 4           Rue de la Boulangerie       83630      83002
# ...                           ...         ...        ...
# 400538         Rue des Muletières       83630      83005
# 400539         Chemin de Fontayne       83630      83005
# 400540               Route d’Aups       83630      83005
# 400541  Impasse de Sainte Trinite       83630      83005
# 400542                Rue du Four       83630      83005
#
#                  nom_commune code_insee_ancienne_commune nom_ancienne_commune  \
# 0                   Aiguines                         NaN                  NaN
# 1                   Aiguines                         NaN                  NaN
# 2                   Aiguines                         NaN                  NaN
# 3                   Aiguines                         NaN                  NaN
# 4                   Aiguines                         NaN                  NaN
# ...                      ...                         ...                  ...
# 400538  Artignosc-sur-Verdon                         NaN                  NaN
# 400539  Artignosc-sur-Verdon                         NaN                  NaN
# 400540  Artignosc-sur-Verdon                         NaN                  NaN
# 400541  Artignosc-sur-Verdon                         NaN                  NaN
# 400542  Artignosc-sur-Verdon                         NaN                  NaN
#
#         ...        lat type_position alias nom_ld  libelle_acheminement  \
# 0       ...  43.776717        entrée   NaN    NaN              AIGUINES
# 1       ...  43.775624        entrée   NaN    NaN              AIGUINES
# 2       ...  43.775336        entrée   NaN    NaN              AIGUINES
# 3       ...  43.775859        entrée   NaN    NaN              AIGUINES
# 4       ...  43.776137        entrée   NaN    NaN              AIGUINES
# ...     ...        ...           ...   ...    ...                   ...
# 400538  ...  43.703074        entrée   NaN    NaN  ARTIGNOSC SUR VERDON
# 400539  ...  43.703245        entrée   NaN    NaN  ARTIGNOSC SUR VERDON
# 400540  ...  43.700649        entrée   NaN    NaN  ARTIGNOSC SUR VERDON
# 400541  ...   43.70193        entrée   NaN    NaN  ARTIGNOSC SUR VERDON
# 400542  ...  43.702761        entrée   NaN    NaN  ARTIGNOSC SUR VERDON
#
#                         nom_afnor source_position source_nom_voie  \
# 0                       RUE HAUTE         commune         commune
# 1                       GRAND RUE         commune         commune
# 2        PLACE SYBILLE DE FORESTA         commune         commune
# 3                     LA PLACETTE         commune         commune
# 4           RUE DE LA BOULANGERIE         commune         commune
# ...                           ...             ...             ...
# 400538         RUE DES MULETIERES         commune         commune
# 400539         CHEMIN DE FONTAYNE         commune         commune
# 400540               ROUTE D AUPS         commune         commune
# 400541  IMPASSE DE SAINTE TRINITE         commune         commune
# 400542                RUE DU FOUR         commune         commune
#
#        certification_commune   cad_parcelles
# 0                          1  830020000C0072
# 1                          1  830020000C0279
# 2                          1  830020000C0410
# 3                          1  830020000C0145
# 4                          1  830020000C0189
# ...                      ...             ...
# 400538                     1             NaN
# 400539                     1             NaN
# 400540                     1  830050000C0568
# 400541                     1             NaN
# 400542                     1             NaN
#
# [400543 rows x 23 columns]
